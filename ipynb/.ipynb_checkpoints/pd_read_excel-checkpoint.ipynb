# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import math
from os.path import isfile, join
from os import listdir
import re

import sys

reload(sys)

sys.setdefaultencoding('utf-8')

# %%
d1 = pd.read_excel('/data/data/big_traffic/smart_city/data/buxiao/alarm_old/地面20170510状态西湖拱墅报警操作记录.xlsx', skiprows = 0, header = 0, sheetname = 'Sheet1', na_values = 'NA')

# %%
d1.columns
# Out:
# Index([u'日期', u'报警时间', u'报警点位名称', u'报警是否正确(是、否）', u'请详细记录相应的控制变更', u'变更下发的时间点',
#        u'变更原因'],
#       dtype='object')

# %%
d1[u'日期'].astype(basestring)
# Out:
# 0      42865
# 1        NaN
# 2      42865
# 3        NaN
# 4      42865
# 5        NaN
# 6      42865
# 7        NaN
# 8      42865
# 9        NaN
# 10     42865
# 11       NaN
# 12     42865
# 13       NaN
# 14     42865
# 15       NaN
# 16     42865
# 17       NaN
# 18     42865
# 19       NaN
# 20     42865
# 21       NaN
# 22     42865
# 23       NaN
# 24     42865
# 25       NaN
# 26     42865
# 27       NaN
# 28     42865
# 29       NaN
#        ...
# 150    42865
# 151      NaN
# 152    42865
# 153      NaN
# 154    42865
# 155      NaN
# 156    42865
# 157      NaN
# 158    42865
# 159      NaN
# 160    42865
# 161      NaN
# 162    42865
# 163      NaN
# 164    42865
# 165      NaN
# 166    42865
# 167      NaN
# 168    42865
# 169      NaN
# 170    42865
# 171      NaN
# 172    42865
# 173      NaN
# 174    42865
# 175      NaN
# 176    42865
# 177      NaN
# 178    42865
# 179      NaN
# Name: 日期, dtype: object

# %%
d1.head(10)
# Out:
#         日期      报警时间       报警点位名称 报警是否正确(是、否）                  请详细记录相应的控制变更  \
# 0  42865.0  07:52:00  文二路-莫干山路(红）           是   西口路况复杂，东口流量较小导致失衡，通行顺畅，无需调控
# 1      NaN       NaN          NaN         NaN                           NaN
# 2  42865.0  08:05:00      余杭塘教工（红           是     南北向车流较大，东西向较空，车流正常，没有拥堵情况
# 3      NaN       NaN          NaN         NaN                           NaN
# 4  42865.0  08:08:00     潮王-湖墅(黄）           是            早高峰车流比较大，通行缓慢，正常情况
# 5      NaN       NaN          NaN         NaN                           NaN
# 6  42865.0  08:10:00  环城北路湖墅南路(红）           是  绿信比（修改前）：A36%,B17%,C25%,D22%
# 7      NaN       NaN          NaN         NaN  绿信比（修改后）：A38%,B17%,C24%,D21%
# 8  42865.0  08:16:00     余杭塘教工（红）           是                    车流正常没有拥堵情况
# 9      NaN       NaN          NaN         NaN                           NaN
#
#    变更下发的时间点    变更原因
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
# ...

# %%
d1[u'日期'].astype(str)
# Out:
# 0      42865.0
# 1          nan
# 2      42865.0
# 3          nan
# 4      42865.0
# 5          nan
# 6      42865.0
# 7          nan
# 8      42865.0
# 9          nan
# 10     42865.0
# 11         nan
# 12     42865.0
# 13         nan
# 14     42865.0
# 15         nan
# 16     42865.0
# 17         nan
# 18     42865.0
# 19         nan
# 20     42865.0
# 21         nan
# 22     42865.0
# 23         nan
# 24     42865.0
# 25         nan
# 26     42865.0
# 27         nan
# 28     42865.0
# 29         nan
#         ...
# 150    42865.0
# 151        nan
# 152    42865.0
# 153        nan
# 154    42865.0
# 155        nan
# 156    42865.0
# 157        nan
# 158    42865.0
# 159        nan
# 160    42865.0
# 161        nan
# 162    42865.0
# 163        nan
# 164    42865.0
# 165        nan
# 166    42865.0
# 167        nan
# 168    42865.0
# 169        nan
# 170    42865.0
# 171        nan
# 172    42865.0
# 173        nan
# 174    42865.0
# 175        nan
# 176    42865.0
# 177        nan
# ...

# %%
d1[u'日期'] = d1[u'日期'].astype(str)

# %%
d1.head(10)
# Out:
#         日期      报警时间       报警点位名称 报警是否正确(是、否）                  请详细记录相应的控制变更  \
# 0  42865.0  07:52:00  文二路-莫干山路(红）           是   西口路况复杂，东口流量较小导致失衡，通行顺畅，无需调控
# 1      nan       NaN          NaN         NaN                           NaN
# 2  42865.0  08:05:00      余杭塘教工（红           是     南北向车流较大，东西向较空，车流正常，没有拥堵情况
# 3      nan       NaN          NaN         NaN                           NaN
# 4  42865.0  08:08:00     潮王-湖墅(黄）           是            早高峰车流比较大，通行缓慢，正常情况
# 5      nan       NaN          NaN         NaN                           NaN
# 6  42865.0  08:10:00  环城北路湖墅南路(红）           是  绿信比（修改前）：A36%,B17%,C25%,D22%
# 7      nan       NaN          NaN         NaN  绿信比（修改后）：A38%,B17%,C24%,D21%
# 8  42865.0  08:16:00     余杭塘教工（红）           是                    车流正常没有拥堵情况
# 9      nan       NaN          NaN         NaN                           NaN
#
#    变更下发的时间点    变更原因
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
# ...

# %%
df = pd.read_excel('/data/data/big_traffic/smart_city/data/buxiao/alarm_old/地面20170510状态西湖拱墅报警操作记录.xlsx', skiprows = 0, header = 0, sheetname = 'Sheet1', na_values = 'NA')

# %%
df.head(10)
# Out:
#         日期      报警时间       报警点位名称 报警是否正确(是、否）                  请详细记录相应的控制变更  \
# 0  42865.0  07:52:00  文二路-莫干山路(红）           是   西口路况复杂，东口流量较小导致失衡，通行顺畅，无需调控
# 1      NaN       NaN          NaN         NaN                           NaN
# 2  42865.0  08:05:00      余杭塘教工（红           是     南北向车流较大，东西向较空，车流正常，没有拥堵情况
# 3      NaN       NaN          NaN         NaN                           NaN
# 4  42865.0  08:08:00     潮王-湖墅(黄）           是            早高峰车流比较大，通行缓慢，正常情况
# 5      NaN       NaN          NaN         NaN                           NaN
# 6  42865.0  08:10:00  环城北路湖墅南路(红）           是  绿信比（修改前）：A36%,B17%,C25%,D22%
# 7      NaN       NaN          NaN         NaN  绿信比（修改后）：A38%,B17%,C24%,D21%
# 8  42865.0  08:16:00     余杭塘教工（红）           是                    车流正常没有拥堵情况
# 9      NaN       NaN          NaN         NaN                           NaN
#
#    变更下发的时间点    变更原因
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
# ...

# %%
dd = pd.read_excel('/data/data/big_traffic/smart_city/data/buxiao/alarm_old/地面5.8状态报警操作记录.xlsx', skiprows = 0, header = 0, sheetname = 'Sheet1', na_values = 'NA',encoding = 'utf-8',dtypes={u'日期':object})
dd[u'日期'] =  pd.to_datetime(dd[u'日期'], format='%Y/%m/%d')

# %%
dd.dtypes
# Out:
# 日期              datetime64[ns]
# 报警时间                    object
# 报警点位名称                  object
# 报警是否正确(是、否）             object
# 请详细记录相应的控制变更            object
# 变更下发的时间点                object
# dtype: object

# %%
dd.head(10)
# Out:
#           日期      报警时间        报警点位名称 报警是否正确(是、否）  \
# 0 2017-05-08  07:00:00      余杭塘教工（黄）           否
# 1        NaT       NaN           NaN         NaN
# 2 2017-05-08  07:20:00     文二-莫干山（黄）           否
# 3        NaT       NaN           NaN         NaN
# 4 2017-05-08  07:30:00  环城北路-湖墅南路（红）           是
# 5        NaT       NaN           NaN         NaN
# 6 2017-05-08  07:40:00     文二-莫干山（红）           是
# 7        NaT       NaN           NaN         NaN
# 8 2017-05-08  07:46:00     文二-莫干山（红）           是
# 9        NaT       NaN           NaN         NaN
#
#                            请详细记录相应的控制变更  变更下发的时间点
# 0                     单一方向上车流一个灯次基本可以清空       NaN
# 1                                   NaN       NaN
# 2                     单一方向上车流一个灯次基本可以清空       NaN
# 3                                   NaN       NaN
# 4           绿信比A37%，B18%，C26%，D19%（修改前）  07:32:00
# 5           绿信比A35%，B16%，C27%，D22%（修改后）       NaN
# 6  绿信比A9%，B11%，C26%，D32%，E10%，F11%（修改前）  07:45:00
# ...

# %%
b = dd[dd[u'报警时间']  ]
b.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-1f9fcacda582> in <module>()
# ----> 1 b = dd[dd[u'报警时间'] != NaN]
#       2 b.head(10)
#
# NameError: name 'NaN' is not defined

# %%
dt = pd.read_excel('/data/data/big_traffic/smart_city/data/buxiao/alarm_old/地面5.8状态报警操作记录.xlsx', skiprows = 0, header = 0, sheetname = 'Sheet1', na_values = 'NA',encoding = 'utf-8',dtypes={u'日期':object})
dt.head(10)
mdd = dt[dt[u'报警时间'] != 'NA' ]
mdd.head(10)
# Out:
#           日期      报警时间        报警点位名称 报警是否正确(是、否）  \
# 0 2017-05-08  07:00:00      余杭塘教工（黄）           否
# 1        NaT       NaN           NaN         NaN
# 2 2017-05-08  07:20:00     文二-莫干山（黄）           否
# 3        NaT       NaN           NaN         NaN
# 4 2017-05-08  07:30:00  环城北路-湖墅南路（红）           是
# 5        NaT       NaN           NaN         NaN
# 6 2017-05-08  07:40:00     文二-莫干山（红）           是
# 7        NaT       NaN           NaN         NaN
# 8 2017-05-08  07:46:00     文二-莫干山（红）           是
# 9        NaT       NaN           NaN         NaN
#
#                            请详细记录相应的控制变更  变更下发的时间点
# 0                     单一方向上车流一个灯次基本可以清空       NaN
# 1                                   NaN       NaN
# 2                     单一方向上车流一个灯次基本可以清空       NaN
# 3                                   NaN       NaN
# 4           绿信比A37%，B18%，C26%，D19%（修改前）  07:32:00
# 5           绿信比A35%，B16%，C27%，D22%（修改后）       NaN
# 6  绿信比A9%，B11%，C26%，D32%，E10%，F11%（修改前）  07:45:00
# ...
